# %%
#import  libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

import scipy.cluster.hierarchy as sch  # to build dendrogram and build the plotting
from sklearn.cluster import AgglomerativeClustering

# %%
#import  dataset
airline=pd.read_csv('/content/EastWestAirlines.csv')
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline1=airline.drop(['ID#'],axis=1)
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#customized Normalization function
# Here we can use standardized functions as well from sklearn but to show you how we can write customized function we used this code
def norm_func(i): ## function name is norm_func
  x=(i-i.min())/(i.max()-i.min())   # (Xi-min)/range (Feature Scaling), Range=max-min
  return x

# %%
# Normalized data frame (only numeriacal data)
airline2=norm_func(airline1.iloc[:,1:])  #all rows  & 1 to 11 colomns

# %%
airline2
# Out:
#       Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0            0.0       0.00        0.0        0.0     0.000660     0.011628
# 1            0.0       0.00        0.0        0.0     0.000815     0.023256
# 2            0.0       0.00        0.0        0.0     0.015636     0.046512
# 3            0.0       0.00        0.0        0.0     0.001896     0.011628
# 4            0.0       0.75        0.0        0.0     0.164211     0.302326
# ...          ...        ...        ...        ...          ...          ...
# 3994         0.0       0.00        0.0        0.0     0.032330     0.046512
# 3995         0.0       0.00        0.0        0.0     0.003720     0.058140
# 3996         0.0       0.50        0.0        0.0     0.096505     0.093023
# 3997         0.0       0.00        0.0        0.0     0.001896     0.011628
# 3998         0.0       0.00        0.0        0.0     0.000000     0.000000
#
# ...

# %%
# create dendrogram
dendrogram = sch.dendrogram(sch.linkage(airline2, method='complete'))

# %%
 #create clusters, suppose got input from customer that go for 4 clusters
# Create Clusters (y)
hclusters=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')
hclusters
# Out:
# AgglomerativeClustering(affinity='euclidean', n_clusters=5)

# %%
y=pd.DataFrame(hclusters.fit_predict(airline2),columns=['clustersid'])
y['clustersid'].value_counts()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# 4    1011
# 0     946
# 1     808
# 3     699
# 2     535
# Name: clustersid, dtype: int64

# %%
# Adding clusters to dataset
airline1['clustersid']=hclusters.labels_
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline1.groupby('clustersid').agg(['mean']).reset_index()
# Out:
#   clustersid        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                        mean        mean      mean      mean      mean
# 0          0   79848.233615  285.097252  1.699789  1.024313  1.000000
# 1          1  106221.111386  161.262376  3.198020  1.001238  1.025990
# 2          2  127475.028037  160.801869  4.362617  1.000000  1.050467
# 3          3   30013.416309   98.054363  1.000000  1.000000  1.000000
# 4          4   43313.653808   21.506429  1.000000  1.033630  1.000989
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  12079.774841   12.133192        781.939746        2.369979
# 1  26458.257426   16.363861        198.733911        0.558168
# 2  58656.919626   22.235514        991.110280        3.005607
# 3   2552.569385    6.101574        340.274678        0.948498
# 4   2562.614243    5.474777        169.510386        0.523244
#
#   Days_since_enroll Award?
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(airline1['clustersid'],airline1['Balance'], c=hclusters.labels_)

# %% [markdown]
# Kmeans Clustering

# %%
#we dont know the no of clusters.so lets use k-means & elbow method to choose this
from sklearn.cluster import KMeans

# %%
# Normalization / Standardisation function 
from sklearn.preprocessing import StandardScaler  # built in function for standardization
scaler = StandardScaler() # scaler is an object name of StandardScalar class, you can give any name
scaled_airline_df = scaler.fit_transform(airline.iloc[:,1:]) # fit_transform() is a method of StandardScalar class
scaled_airline_df
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.39545434e+00, -7.66919299e-01, -6.09176780e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.37995704e+00, -7.66919299e-01, -6.09176780e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.41192021e+00, -7.66919299e-01, -6.09176780e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -1.31560393e+00,  1.30391816e+00,  1.42429396e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31608822e+00, -7.66919299e-01, -6.09176780e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31754109e+00, -7.66919299e-01, -6.09176780e-01]])

# %%
wcss = [] # within cluster sum of square. Initialize WCSS and begin the loop
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,random_state=0)
    kmeans.fit(scaled_airline_df) 
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [43989.000000000015,
#  35409.511452424376,
#  30899.24682465222,
#  27446.372456681347,
#  24541.329582045757,
#  21089.973628929638,
#  19165.86145865565,
#  17316.866446128264,
#  16043.406242309495,
#  14726.983322766802]

# %%
kmeans = KMeans(n_clusters=5,random_state=0) # pass no. of clusters as 5
predict=kmeans.fit_predict(scaled_airline_df)# assign cluster numbers to airline
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
predict
# Out:
# array([0, 0, 0, ..., 2, 0, 0], dtype=int32)

# %%
clusters_new= KMeans(n_clusters=5,random_state=42)
new_predict=clusters_new.fit_predict(scaled_airline_df)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
clusters_new.labels_
# Out:
# array([1, 1, 1, ..., 3, 1, 1], dtype=int32)

# %%
#assign cluster to dataset
airline['clusterid_new']=new_predict

# %%
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
#these are stanadardized values
clusters_new.cluster_centers_
# Out:
# array([[ 1.13984539,  1.05672065,  0.09776869, -0.09824189, -0.06276658,
#          0.57151541,  1.51103346,  3.44127553,  3.6610428 ,  0.27107706,
#          0.88975067],
#        [-0.29035586, -0.05818754, -0.59651518, -0.09824189, -0.06074586,
#         -0.51420592, -0.49040819, -0.18783605, -0.19980876, -0.20213465,
#         -0.34539972],
#        [-0.04688966, -0.1562356 , -0.66822727,  9.03825361, -0.06276658,
#         -0.10166533,  0.61785114,  0.0875494 ,  0.22034681, -0.07246398,
#          0.05178388],
#        [ 0.43260424, -0.01954084,  1.22083157, -0.09824189, -0.05447771,
#          0.94096329,  0.75568144, -0.09151819, -0.10212979,  0.37689814,
#          0.58013031],
#        [ 0.63971926, -0.08443292,  1.0220844 , -0.09824189, 15.64629931,
#          3.17969131,  1.71461374,  0.03329269,  0.05969539,  0.23987261,
#          0.33752735]])

# %%
airline.groupby('clusterid_new').agg(['mean']).reset_index()
# Out:
#   clusterid_new          ID#        Balance  Qual_miles cc1_miles cc2_miles  \
#                         mean           mean        mean      mean      mean
# 0             0  1731.100000  188455.641176  961.558824  2.194118  1.000000
# 1             1  2237.743286   44293.077409   98.530806  1.237362  1.000000
# 2             2  2269.372093   68876.581395   23.255814  1.139535  2.348837
# 3             3  1593.586764  117119.906376  130.094431  3.736077  1.000000
# 4             4  1664.866667  138061.400000   78.800000  3.466667  1.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.000000  30945.770588   26.111765       5277.958824       15.258824
# 1  1.000395   4722.390205    6.885861        196.838468        0.614929
# 2  1.000000  14689.837209   17.534884        582.627907        2.209302
# 3  1.001614  39793.209040   18.843422        332.092010        0.987086
# ...

# %%
airline[airline['clusterid_new']==0]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 21      22   185681        2024          1          1          1        13300
# 22      23    20584           0          1          1          1         3450
# 42      43    60313           0          1          1          1        10000
# 50      51   108137           0          1          1          1         6368
# 65      66    53914           0          3          1          1        33767
# ...    ...      ...         ...        ...        ...        ...          ...
# 3907  3930   126490           0          1          1          1         8808
# 3911  3934    55922        2273          1          1          1         8104
# 3917  3940   130748           0          4          1          1        65510
# 3934  3957    76595           0          1          1          1        10577
# 3950  3973    59650           0          1          1          1         5050
#
# ...

# %% [markdown]
# DBScan

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
array=airline2.values
array
# Out:
# array([[0.01650773, 0.        , 0.        , ..., 0.        , 0.84374246,
#         0.        ],
#        [0.01128788, 0.        , 0.        , ..., 0.        , 0.83988425,
#         0.        ],
#        [0.02425685, 0.        , 0.        , ..., 0.        , 0.84784181,
#         0.        ],
#        ...,
#        [0.0431695 , 0.        , 0.5       , ..., 0.        , 0.16879672,
#         1.        ],
#        [0.03220189, 0.        , 0.        , ..., 0.01886792, 0.16867615,
#         0.        ],
#        [0.00176908, 0.        , 0.        , ..., 0.        , 0.16831444,
#         0.        ]])

# %%
stscaler=StandardScaler() #apply standardization on dataset
X=stscaler.fit_transform(array)

# %%
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
dbscan=DBSCAN(eps=0.8,min_samples=4) # creating instance  dbscan of DBSCAN class with eps and min_samples parameters
dbscan.fit_predict(X)
# Out:
# array([0, 0, 0, ..., 2, 0, 0])

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 2, 0, 0])

# %%
dbscan=DBSCAN(eps=0.8,min_samples=2)
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.8, min_samples=2)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])
